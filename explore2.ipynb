# %%
import numpy as np
import pandas as pd
import math
from sklearn import metrics

from scipy.stats import entropy

import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates #to format dates on our plots
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses? Any odd user-agents?

# %%
import requests

# %%
df = pd.read_csv('curriculum.txt',
                engine='python',
                 header=None,
                 index_col=False,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',)

# %%
df.columns = ['date', 'time', 'page_viewed', 'user_id', 'cohort_id', 'ip']

# %%
cohort = pd.read_csv('cohort_name.csv')

# %%
cohort.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN  cohort_id       name  start_date    end_date  program_id
# 1         NaN          1     Arches  2014-02-04  2014-04-22           1
# 2         NaN          2   Badlands  2014-06-04  2014-08-22           1
# 3         NaN          3   Carlsbad  2014-09-04  2014-11-05           1
# 4         NaN          4     Denali  2014-10-20  2015-01-18           1
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
cohort.columns = cohort.iloc[0]

# %%
cohort = cohort.iloc[1:]

# %%
cohort.head()
# Out:
# 0  NaN cohort_id        name  start_date    end_date program_id  NaN
# 1  NaN         1      Arches  2014-02-04  2014-04-22          1  NaN
# 2  NaN         2    Badlands  2014-06-04  2014-08-22          1  NaN
# 3  NaN         3    Carlsbad  2014-09-04  2014-11-05          1  NaN
# 4  NaN         4      Denali  2014-10-20  2015-01-18          1  NaN
# 5  NaN         5  Everglades  2014-11-18  2015-02-24          1  NaN

# %%
cohort = cohort[['cohort_id', 'name', 'start_date', 'end_date']]

# %%
cohort.cohort_id = cohort.cohort_id.astype('int')

# %%
result = pd.merge(df, cohort, on='cohort_id')

# %%
result.cohort_id = result.cohort_id.astype('int')
result['date'] = result.date + " " + result.time
result.drop(columns=('time'), inplace=True)
result.date = pd.to_datetime(result.date)
result = result.set_index('date')

# %%
data_science = result[(result.name == 'Curie') | (result.name == 'Bayes') | (result.name == 'Ada') | (result.name == 'Darden')]

# %%
web_dev = result[(result.name != 'Curie') & (result.name != 'Bayes') & (result.name != 'Ada') & (result.name != 'Darden')]

# %%
bayes = data_science[data_science.name == 'Bayes']

# %%
darden = data_science[data_science.name == 'Darden']

# %%
curie = data_science[data_science.name == 'Curie']

# %%
# for index, row in darden.iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[5:6])
#     print(res[5:6])

# %%
ips = darden.ip.unique()

# %%
ips.shape
# Out:
# (155,)

# %%
ips = pd.DataFrame(ips)

# %%
ips
# Out:
#                    0
# 0      76.201.20.193
# 1      24.28.146.155
# 2      136.50.56.155
# 3    108.239.188.205
# 4      68.54.110.249
# ..               ...
# 150   172.58.110.195
# 151    172.58.67.160
# 152    107.13.184.11
# 153   72.128.139.130
# 154   172.58.107.212
#
# [155 rows x 1 columns]

# %%
ips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       155 non-null    object
# dtypes: object(1)
# memory usage: 1.3+ KB

# %%
ips.rename(columns={0: 'ip'}, inplace=True)

# %%
ips
# Out:
#                   ip
# 0      76.201.20.193
# 1      24.28.146.155
# 2      136.50.56.155
# 3    108.239.188.205
# 4      68.54.110.249
# ..               ...
# 150   172.58.110.195
# 151    172.58.67.160
# 152    107.13.184.11
# 153   72.128.139.130
# 154   172.58.107.212
#
# [155 rows x 1 columns]

# %%
# for index, row in ips.iloc[:45].iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[4:6])
#     print(row['ip'],res[4:6])

# %% [markdown]
# function for a single value, with response data. (.apply)

# %%
darden.shape

# %%
# for index, row in ips.iloc[46:90].iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[4:6])
#     print(row['ip'],res[4:6])

# %%
# for index, row in ips.iloc[91:130].iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[4:6])
#     print(row['ip'],res[4:6])

# %%
# for index, row in ips.iloc[131:180].iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[4:6])
#     print(row['ip'],res[4:6])

# %%
# for index, row in ips.iloc[181:220].iterrows():
#     location = row['ip']
#     url = 'http://ip-api.com/csv/' + location
#     response = requests.get(url)
#     res = response.text.split(',')
#     location = []
#     location.append(res[4:6])
#     print(row['ip'],res[4:6])

# %%
darden.shape

# %%
d = []

# %%
import requests

for index, row in ips.iterrows():
    location = row['ip']
    url = "https://free-geo-ip.p.rapidapi.com/json/" + location

    headers = {
        'x-rapidapi-key': "e971744d3fmshe67b5c357e7ec4ap1aa107jsn4a07ff9a4175",
        'x-rapidapi-host': "free-geo-ip.p.rapidapi.com"
        }

    response = requests.request("GET", url, headers=headers)

    data = response.json()
    d.append(
        {
            'ip': row['ip'],
            'city': data['city']
            
        }
    )

pd.DataFrame(d)
# Out:
#                   ip         city
# 0      76.201.20.193       Austin
# 1      24.28.146.155  San Antonio
# 2      136.50.56.155  San Antonio
# 3    108.239.188.205  San Antonio
# 4      68.54.110.249   Burnsville
# ..               ...          ...
# 150   172.58.110.195       Dallas
# 151    172.58.67.160       Irving
# 152    107.13.184.11      Raleigh
# 153   72.128.139.130  San Antonio
# 154   172.58.107.212       Dallas
#
# [155 rows x 2 columns]

# %%
d
# Out:
# [{'ip': '76.201.20.193', 'city': 'Austin'},
#  {'ip': '24.28.146.155', 'city': 'San Antonio'},
#  {'ip': '136.50.56.155', 'city': 'San Antonio'},
#  {'ip': '108.239.188.205', 'city': 'San Antonio'},
#  {'ip': '68.54.110.249', 'city': 'Burnsville'},
#  {'ip': '173.174.165.12', 'city': 'San Antonio'},
#  {'ip': '70.120.16.59', 'city': 'San Antonio'},
#  {'ip': '99.76.233.212', 'city': 'San Antonio'},
#  {'ip': '72.177.148.181', 'city': 'San Antonio'},
#  {'ip': '96.8.130.195', 'city': 'San Antonio'},
#  {'ip': '99.203.26.91', 'city': 'Houston'},
#  {'ip': '99.203.27.127', 'city': 'Houston'},
#  {'ip': '99.203.155.22', 'city': 'Houston'},
#  {'ip': '99.203.27.94', 'city': 'Houston'},
#  {'ip': '162.71.236.112', 'city': 'Marshall'},
#  {'ip': '96.8.130.143', 'city': 'San Antonio'},
#  {'ip': '99.203.27.141', 'city': 'Houston'},
#  {'ip': '70.120.27.3', 'city': 'San Antonio'},
#  {'ip': '70.114.45.119', 'city': 'San Antonio'},
#  {'ip': '99.203.27.142', 'city': 'Houston'},
#  {'ip': '67.11.56.165', 'city': 'San Antonio'},
#  {'ip': '99.203.154.98', 'city': 'Houston'},
#  {'ip': '72.178.76.70', 'city': 'Killeen'},
#  {'ip': '96.8.130.212', 'city': 'San Antonio'},
#  {'ip': '72.181.103.160', 'city': 'San Antonio'},
#  {'ip': '99.203.27.32', 'city': 'Houston'},
#  {'ip': '99.203.26.216', 'city': 'Houston'},
#  {'ip': '96.8.130.213', 'city': 'San Antonio'},
#  {'ip': '99.203.27.90', 'city': 'Houston'},
#  {'ip': '67.11.185.145', 'city': 'San Antonio'},
#  {'ip': '24.28.150.196', 'city': 'San Antonio'},
#  {'ip': '99.203.155.120', 'city': 'Houston'},
#  {'ip': '99.203.154.146', 'city': 'Houston'},
#  {'ip': '99.203.154.222', 'city': 'Houston'},
#  {'ip': '66.69.67.230', 'city': 'San Antonio'},
#  {'ip': '99.203.27.111', 'city': 'Houston'},
#  {'ip': '107.77.218.55', 'city': 'Houston'},
#  {'ip': '107.77.218.100', 'city': 'Houston'},
#  {'ip': '172.58.67.200', 'city': 'Irving'},
#  {'ip': '99.203.154.100', 'city': 'Houston'},
#  {'ip': '96.8.130.240', 'city': 'San Antonio'},
#  {'ip': '107.77.219.35', 'city': 'Houston'},
#  {'ip': '99.203.40.221', 'city': 'Phoenix'},
#  {'ip': '172.58.99.71', 'city': 'Houston'},
#  {'ip': '76.186.27.252', 'city': 'Austin'},
#  {'ip': '71.146.34.33', 'city': 'Cibolo'},
#  {'ip': '172.58.110.195', 'city': 'Dallas'},
#  {'ip': '172.58.67.160', 'city': 'Irving'},
#  {'ip': '107.13.184.11', 'city': 'Raleigh'},
#  {'ip': '72.128.139.130', 'city': 'San Antonio'},
#  {'ip': '172.58.107.212', 'city': 'Dallas'}]

# %%
d = pd.DataFrame(d)

# %%
d
# Out:
#                   ip         city
# 0      76.201.20.193       Austin
# 1      24.28.146.155  San Antonio
# 2      136.50.56.155  San Antonio
# 3    108.239.188.205  San Antonio
# 4      68.54.110.249   Burnsville
# ..               ...          ...
# 150   172.58.110.195       Dallas
# 151    172.58.67.160       Irving
# 152    107.13.184.11      Raleigh
# 153   72.128.139.130  San Antonio
# 154   172.58.107.212       Dallas
#
# [155 rows x 2 columns]

# %%
d.groupby('city')[['ip']].agg('count').sort_values(by='ip',ascending=False)
# Out:
#              ip
# city
# Houston      77
# San Antonio  47
# Dallas        6
# Austin        3
# Cypress       2
# Irving        2
#               1
# Marshall      1
# Royse City    1
# Raleigh       1
# Phoenix       1
# Pasadena      1
# Omaha         1
# Minneapolis   1
# Katy          1
# Marfa         1
# Killeen       1
# Harlingen     1
# Devine        1
# Dale          1
# Cibolo        1
# Burnsville    1
# Boerne        1
# Waco          1

# %%
result = pd.merge(darden, d, on='ip', how='left')

# %%
result.head(20)
# Out:
#                                  page_viewed  user_id  cohort_id  \
# 0                                          /      678         59
# 1                                          /      679         59
# 2                                          /      680         59
# 3             13-advanced-topics/1-tidy-data      679         59
# 4   1-fundamentals/1.1-intro-to-data-science      679         59
# 5       1-fundamentals/AI-ML-DL-timeline.jpg      679         59
# 6   1-fundamentals/modern-data-scientist.jpg      679         59
# 7                                          /      681         59
# 8                                          /      682         59
# 9                                          /      683         59
# 10  1-fundamentals/1.1-intro-to-data-science      681         59
# 11  1-fundamentals/modern-data-scientist.jpg      681         59
# 12      1-fundamentals/AI-ML-DL-timeline.jpg      681         59
# 13                                         /      684         59
# 14  1-fundamentals/1.1-intro-to-data-science      682         59
# 15  1-fundamentals/modern-data-scientist.jpg      682         59
# 16      1-fundamentals/AI-ML-DL-timeline.jpg      682         59
# 17                                         /      685         59
# 18  1-fundamentals/1.1-intro-to-data-science      684         59
# 19  1-fundamentals/modern-data-scientist.jpg      684         59
#
#                  ip    name  start_date    end_date         city
# 0     76.201.20.193  Darden  2020-07-13  2021-01-12       Austin
# 1     24.28.146.155  Darden  2020-07-13  2021-01-12  San Antonio
# 2     136.50.56.155  Darden  2020-07-13  2021-01-12  San Antonio
# 3     24.28.146.155  Darden  2020-07-13  2021-01-12  San Antonio
# 4     24.28.146.155  Darden  2020-07-13  2021-01-12  San Antonio
# 5     24.28.146.155  Darden  2020-07-13  2021-01-12  San Antonio
# 6     24.28.146.155  Darden  2020-07-13  2021-01-12  San Antonio
# 7   108.239.188.205  Darden  2020-07-13  2021-01-12  San Antonio
# 8     68.54.110.249  Darden  2020-07-13  2021-01-12   Burnsville
# 9    173.174.165.12  Darden  2020-07-13  2021-01-12  San Antonio
# 10  108.239.188.205  Darden  2020-07-13  2021-01-12  San Antonio
# 11  108.239.188.205  Darden  2020-07-13  2021-01-12  San Antonio
# 12  108.239.188.205  Darden  2020-07-13  2021-01-12  San Antonio
# 13     70.120.16.59  Darden  2020-07-13  2021-01-12  San Antonio
# 14    68.54.110.249  Darden  2020-07-13  2021-01-12   Burnsville
# 15    68.54.110.249  Darden  2020-07-13  2021-01-12   Burnsville
# 16    68.54.110.249  Darden  2020-07-13  2021-01-12   Burnsville
# 17    99.76.233.212  Darden  2020-07-13  2021-01-12  San Antonio
# 18     70.120.16.59  Darden  2020-07-13  2021-01-12  San Antonio
# 19     70.120.16.59  Darden  2020-07-13  2021-01-12  San Antonio
